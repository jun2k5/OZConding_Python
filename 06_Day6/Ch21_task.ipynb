# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter21 ~ 32 수업은 잘 들으셨나요?
#
# Chapter21 ~ 32의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
# 사용자로부터 이름과 나이를 입력 받아, "안녕하세요, [이름]님! 당신은 [나이]살입니다."라고 출력하는 함수 greet_user를 작성하세요.

# %% [markdown]
# def greet_user(name:str, age:int):
#     print(f"안녕하세요, {name}님! 당신은 {age}살입니다.")

# %% [markdown]
# ---

# %% [markdown]
# [문제 2] 여러 숫자를 입력받아 그 합계를 반환하는 함수 sum_numbers를 작성하세요. 이 때, 가변 매개변수를 사용하세요.

# %% [markdown]
# def sum_numbers(*numbers:int) -> int:
#     return sum(numbers)

# %% [markdown]
# ---

# %% [markdown]
# [문제 3] 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %% [markdown]
# def print_name(name:str="익명"):
#     print(name)

# %% [markdown]
# ---

# %% [markdown]
# [문제 4] 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %% [markdown]
# def print_info(*, name:str, age:int, man:bool):
#     print(name, age, man)
#
# print_info(man=True, name="user", age="20")

# %% [markdown]
# ---

# %% [markdown]
# [문제 5] 두 개의 정수를 받아 합을 반환하는 함수 add를 작성하세요. 매개변수와 반환값에 타입 어노테이션을 추가하세요.

# %% [markdown]
# def add(num1:int, num2:int) -> int:
#     return num1 + num2

# %% [markdown]
# ---

# %% [markdown]
# [문제 6] 0부터 시작하여 n까지의 숫자 중에서 홀수만 생성하는 제너레이터 odd_numbers를 작성하세요.

# %% [markdown]
# def odd_numbers(n:int):
#     start = 1
#     while start <= n:
#         yield start
#         start += 2
#
# n = 10
# out_put = odd_numbers(n)
# print(out_put.__next__())
# print(out_put.__next__())
# print(out_put.__next__())
# print(out_put.__next__())
# print(out_put.__next__())

# %% [markdown]
# ---

# %% [markdown]
# [문제 7] 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %% [markdown]
# x = lambda a, b : a + b
# print(x(10, 20))

# %% [markdown]
# ---

# %% [markdown]
# [문제 8] 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %% [markdown]
# def min_max():
#     usr_input = []
#     for i in range(3):
#         usr_input.append(int(input()))
#
#     tuple(usr_input)
#
#     return min(usr_input), max(usr_input)
#
# print(min_max())

# %% [markdown]
# ---

# %% [markdown]
# [문제 9] 주어진 숫자가 짝수인지 확인하는 함수 is_even을 작성하세요. 짝수라면 True를, 아니라면 False를 반환하세요. 함수 내에서 조기 리턴을 활용하세요.

# %% [markdown]
# def is_even(n:int) -> bool:
#     if n % 2 == 0:
#         return True
#     return False
#
# print(is_even(1))
# print(is_even(2))

# %% [markdown]
# ---

# %% [markdown]
# [문제 10] 팩토리얼을 계산하는 재귀 함수 factorial을 작성하세요.

# %% [markdown]
# def factorial(n:int) -> int:
#     if n == 1:
#         return 1
#     else:
#         return n + factorial(n-1)

# %% [markdown]
# ---

# %% [markdown]
# [문제 11] 문자열 리스트를 받아, 각 문자열의 길이를 출력하는 함수 print_lengths를 작성하세요.

# %% [markdown]
# def print_lengths(s_list:list[str]) -> None:
#     for i in s_list:
#         print(len(i))

# %% [markdown]
# ---

# %% [markdown]
# [문제 12] 두 문자열을 받아서 긴 문자열을 반환하는 함수 longer_string을 작성하세요. 만약 두 문자열의 길이가 같다면, 첫 번째 문자열을 반환하세요.

# %% [markdown]
# def longer_string(s1:str, s2:str) -> str:
#     return s1 if len(s1) > len(s2) else s2
